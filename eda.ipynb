# %%
from sklearn import preprocessing
import pandas as pd
import numpy as np
import matplotlib.py

df = pd.read_csv("/content/drive/MyDrive/exp56/hack/Complete-Dataset.zip (Unzipped Files)/Complete Dataset/Phising_Training_Dataset.zip (Unzipped Files)/Phising_Training_Dataset.csv")

# %%
df.head()
# Out:
#      key  having_IP  URL_Length  Shortining_Service  having_At_Symbol  \
# 0  12344         -1           1                   1                 1
# 1  12345          1           1                   1                 1
# 2  12346          1           0                   1                 1
# 3  12347          1           0                   1                 1
# 4  12348          1           0                  -1                 1
#
#    double_slash_redirecting  Prefix_Suffix  having_Sub_Domain  SSLfinal_State  \
# 0                        -1             -1                 -1              -1
# 1                         1             -1                  0               1
# 2                         1             -1                 -1              -1
# 3                         1             -1                 -1              -1
# 4                         1             -1                  1               1
#
#    Domain_registeration_length  ...  popUpWidnow  Iframe  age_of_domain  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8955 entries, 0 to 8954
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   key                          8955 non-null   int64
#  1   having_IP                    8955 non-null   int64
#  2   URL_Length                   8955 non-null   int64
#  3   Shortining_Service           8955 non-null   int64
#  4   having_At_Symbol             8955 non-null   int64
#  5   double_slash_redirecting     8955 non-null   int64
#  6   Prefix_Suffix                8955 non-null   int64
#  7   having_Sub_Domain            8955 non-null   int64
#  8   SSLfinal_State               8955 non-null   int64
#  9   Domain_registeration_length  8955 non-null   int64
#  10  Favicon                      8955 non-null   int64
#  11  port                         8955 non-null   int64
#  12  HTTPS_token                  8955 non-null   int64
# ...

# %%
df['Result'].value_counts()
# Out:
#  1    5034
# -1    3921
# Name: Result, dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# 12344    1
# 18316    1
# 18310    1
# 18311    1
# 18312    1
#         ..
# 15323    1
# 15322    1
# 15321    1
# 15320    1
# 21298    1
# Name: key, Length: 8955, dtype: int64
#  1    5853
# -1    3102
# Name: having_IP, dtype: int64
# -1    7267
#  1    1574
#  0     114
# Name: URL_Length, dtype: int64
#  1    7793
# -1    1162
# Name: Shortining_Service, dtype: int64
#  1    7654
# -1    1301
# Name: having_At_Symbol, dtype: int64
#  1    7794
# -1    1161
# Name: double_slash_redirecting, dtype: int64
# -1    7770
#  1    1185
# Name: Prefix_Suffix, dtype: int64
#  1    3336
#  0    2926
# -1    2693
# Name: having_Sub_Domain, dtype: int64
#  1    5189
# -1    2820
#  0     946
# Name: SSLfinal_State, dtype: int64
# -1    5984
#  1    2971
# Name: Domain_registeration_length, dtype: int64
#  1    7268
# -1    1687
# Name: Favicon, dtype: int64
#  1    7770
# -1    1185
# Name: port, dtype: int64
#  1    7460
# -1    1495
# Name: HTTPS_token, dtype: int64
#  1    5333
# ...

# %%
# !pip install pymrmr
# Out:
# ...
#      |████████████████████████████████| 69 kB 2.8 MB/s
# ...
#   Created wheel for pymrmr: filename=pymrmr-0.1.11-cp37-cp37m-linux_x86_64.whl size=276661 sha256=cb4f46b3e3cf2389bb6c06affd1effcb8e828f96a7ea836d4b4e8764b26e956e
#   Stored in directory: /root/.cache/pip/wheels/81/95/66/05731ac334bc74a1251a727af18eb28dc027217ee817a0cab6
# Successfully built pymrmr
# ...

# %%
#using  mRMR (minimum Redundancy Maximum Relevance) for feature selection

import pymrmr
pymrmr.mRMR(df,"MIQ",5) #MIQ = Mutual Information Quotient
# Out:
# ['having_Sub_Domain', 'port', 'HTTPS_token', 'web_traffic', 'URL_Length']

# %%
pymrmr.mRMR(df,"MIQ",10)
# Out:
# ['having_Sub_Domain',
#  'port',
#  'HTTPS_token',
#  'web_traffic',
#  'URL_Length',
#  'Google_Index',
#  'Links_in_tags',
#  'Page_Rank',
#  'Links_pointing_to_page',
#  'age_of_domain']

# %%
pymrmr.mRMR(df,"MIQ",15)
# Out:
# ['having_Sub_Domain',
#  'port',
#  'HTTPS_token',
#  'web_traffic',
#  'URL_Length',
#  'Google_Index',
#  'Links_in_tags',
#  'Page_Rank',
#  'Links_pointing_to_page',
#  'age_of_domain',
#  'Prefix_Suffix',
#  'Domain_registeration_length',
#  'Statistical_report',
#  'SFH',
#  'having_At_Symbol']
